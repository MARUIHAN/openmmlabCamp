# %% [markdown]
# # 进入mmdetection

# %%
import os
os.chdir('mmdetection')

# %%
os.getcwd()
# Out:
# '/mnt/openmmlab-Camp/01-mmpose-task/mmdetection'

# %% [markdown]
# # 预测单张图片-自己耳朵

# %%
# !/root/miniconda3/envs/myconda/bin/python demo/image_demo.py \
        mydata/myEar.jpg \
        ../mmpose/MMPoseHomework/configs/rtmdet_tiny_ear.py \
        --weights work_dirs/rtmdet_tiny_ear/epoch_80.pth \
        --out-dir outputs/ \
        --device cuda:0 \
        --pred-score-thr 0.5
# Out:
# Loads checkpoint by local backend from path: work_dirs/rtmdet_tiny_ear/epoch_80.pth
# 06/04 00:40:35 - mmengine - WARNING - Failed to search registry with scope "mmdet" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet" is a correct scope, or whether the registry is initialized.
# 06/04 00:40:35 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/torch/functional.py:47━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 8: UserWarning: torch.meshgrid: in an upcoming release, it will be required to
# pass the indexing argument. (Triggered internally at
# ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Inference ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ...

# %%
# 查看预测出来的图片
import cv2
import matplotlib.pyplot as plt

img=cv2.imread('outputs/vis/myEar.jpg')

plt.imshow(img)

plt.show()

# %% [markdown]
# # 预测视频——自己的耳朵

# %%
# !/root/miniconda3/envs/myconda/bin/python demo/video_demo.py \
        mydata/ear.mp4 \
        MMPoseHomework/configs/rtmdet_tiny_ear.py \
        work_dirs/rtmdet_tiny_ear/epoch_70.pth \
        --device cuda:0 \
        --score-thr 0.96 \
        --out outputs/my_ear.mp4
# Out:
# Loads checkpoint by local backend from path: work_dirs/rtmdet_tiny_ear/epoch_60.pth
# 06/03 12:03:01 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# [                                                  ] 0/238, elapsed: 0s, ETA:/root/miniconda3/envs/myconda/lib/python3.8/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 238/238, 6.8 task/s, elapsed: 35s, ETA:     0s
