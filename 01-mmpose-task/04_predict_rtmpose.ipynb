# %% [markdown]
# # 进入mmpose

# %%
import os 
os.chdir('mmpose')

# %%
os.getcwd()
# Out:
# '/mnt/openmmlab-Camp/01-mmpose-task/mmpose'

# %% [markdown]
# # 预测单张图片

# %%
# RTMDet --> RTMPose
# !/root/miniconda3/envs/myconda/bin/python demo/topdown_demo_with_mmdet.py \
        MMPoseHomework/configs/rtmdet_tiny_ear.py \
        ../mmdetection/work_dirs/rtmdet_tiny_ear/epoch_80.pth \
        MMPoseHomework/configs/rtmpose-s-ear.py \
        work_dirs/rtmpose-s-ear/best_PCK_epoch_290.pth \
        --input mydata/myEar.jpg \
        --output-root outputs \
        --device cuda:0 \
        --bbox-thr 0.5 \
        --kpt-thr 0.5 \
        --nms-thr 0.5 \
        --radius 1 \
        --thickness 1 \
        --draw-bbox \
        --draw-heatmap \
        --show-kpt-idx
# Out:
# Loads checkpoint by local backend from path: ../mmdetection/work_dirs/rtmdet_tiny_ear/epoch_80.pth
# Loads checkpoint by local backend from path: work_dirs/rtmpose-s-ear/best_PCK_epoch_290.pth
# 06/04 00:37:14 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /root/miniconda3/envs/myconda/lib/python3.8/site-packages/mmpose/models/heads/coord_cls_heads/rtmcc_head.py:217: UserWarning: The predicted simcc values are normalized for visualization. This may cause discrepancy between the keypoint scores and the 1D heatmaps.
#   warnings.warn('The predicted simcc values are normalized for '

# %%
# 查看预测出来的图片
import cv2
import matplotlib.pyplot as plt

img=cv2.imread('outputs/myEar.jpg')

plt.imshow(img)

plt.show()
